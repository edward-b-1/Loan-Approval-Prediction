# %% [markdown]
# # Plot

# %%
import math
import pandas
import numpy
import itertools
import matplotlib.pyplot as plt

# %%
filename = 'random_forest_3_state_space_search_max_depth.csv'

# %%
df = pandas.read_csv(filename, index_col=0)

# %%
df
# Out:
#       estimators  max_features  max_depth  min_samples_split  \
# 0          100.0           5.0        1.0                2.0
# 1          100.0           5.0        1.0                2.0
# 2          100.0           5.0        1.0                2.0
# 3          100.0           5.0        1.0                2.0
# 4          100.0           5.0        1.0                2.0
# ...          ...           ...        ...                ...
# 2895       100.0           5.0        NaN                2.0
# 2896       100.0           5.0        NaN                2.0
# 2897       100.0           5.0        NaN                2.0
# 2898       100.0           5.0        NaN                2.0
# 2899       100.0           5.0        NaN                2.0
#
#       min_samples_leaf  max_leaf_nodes  fold  accuracy_in_sample  \
# 0                  1.0             NaN     0            0.833486
# 1                  1.0             NaN     1            0.841819
# 2                  1.0             NaN     2            0.833370
# 3                  1.0             NaN     3            0.833196
# 4                  1.0             NaN     4            0.833104
# ...                ...             ...   ...                 ...
# 2895               1.0             NaN    95            0.999931
# 2896               1.0             NaN    96            0.999965
# 2897               1.0             NaN    97            0.999965
# 2898               1.0             NaN    98            0.999931
# 2899               1.0             NaN    99            0.999931
#
#       accuracy_out_of_sample  oob_score       auc  public_score  private_score
# 0                   0.830470   0.837421  0.826785           NaN            NaN
# 1                   0.832761   0.839481  0.879897           NaN            NaN
# 2                   0.823597   0.833428  0.892220           NaN            NaN
# 3                   0.840779   0.833879  0.892552           NaN            NaN
# 4                   0.849943   0.833682  0.885450           NaN            NaN
# ...                      ...        ...       ...           ...            ...
# 2895                0.947248   0.946946  0.949389           NaN            NaN
# 2896                0.948394   0.946460  0.939197           NaN            NaN
# 2897                0.943807   0.947027  0.938962           NaN            NaN
# 2898                0.936927   0.946633  0.936619           NaN            NaN
# 2899                0.943807   0.946575  0.922359           NaN            NaN
#
# [2900 rows x 13 columns]

# %%
plt.figure()

positions = []
x = []
column = 'max_depth'
metric = 'accuracy_in_sample'
x_label = 'maximum depth'
y_label = 'in sample accuracy'
box_width = 0.04
x_min = 0.9
x_max = 110

for value in sorted(df[column].unique()):
    x.append(df[df[column] == value][metric])
    positions.append(value)

plt.boxplot(
    x,
    positions=positions,
    orientation='vertical',
    meanline=True,
    showmeans=True,
    widths=[box_width * position for position in positions],
)
plt.xscale('log')
plt.xlim(xmin=x_min, xmax=x_max)
plt.xlabel(x_label)
plt.ylabel(y_label)

None

# %%
plt.figure()

positions = []
x = []
column = 'max_depth'
metric = 'accuracy_out_of_sample'
x_label = 'maximum depth'
y_label = 'out of sample accuracy'
box_width = 0.04
x_min = 0.9
x_max = 110

for value in sorted(df[column].unique()):
    x.append(df[df[column] == value][metric])
    positions.append(value)

plt.boxplot(
    x,
    positions=positions,
    orientation='vertical',
    meanline=True,
    showmeans=True,
    widths=[box_width * position for position in positions],
)
plt.xscale('log')
plt.xlim(xmin=x_min, xmax=x_max)
plt.xlabel(x_label)
plt.ylabel(y_label)

None

# %%
plt.figure()

positions = []
x = []
column = 'max_depth'
metric = 'oob_score'
x_label = 'maximum depth'
y_label = 'out of bag score'
box_width = 0.04
x_min = 0.9
x_max = 110

for value in sorted(df[column].unique()):
    x.append(df[df[column] == value][metric])
    positions.append(value)

plt.boxplot(
    x,
    positions=positions,
    orientation='vertical',
    meanline=True,
    showmeans=True,
    widths=[box_width * position for position in positions],
)
plt.xscale('log')
plt.xlim(xmin=x_min, xmax=x_max)
plt.xlabel(x_label)
plt.ylabel(y_label)

None

# %%
plt.figure()

positions = []
x = []
column = 'max_depth'
metric = 'auc'
x_label = 'maximum depth'
y_label = 'AUC'
box_width = 0.04
x_min = 0.9
x_max = 110

for value in sorted(df[column].unique()):
    x.append(df[df[column] == value][metric])
    positions.append(value)

plt.boxplot(
    x,
    positions=positions,
    orientation='vertical',
    meanline=True,
    showmeans=True,
    widths=[box_width * position for position in positions],
)
plt.xscale('log')
plt.xlim(xmin=x_min, xmax=x_max)
plt.xlabel(x_label)
plt.ylabel(y_label)

None
