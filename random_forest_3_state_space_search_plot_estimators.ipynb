# %% [markdown]
# # Plot

# %%
import math
import pandas
import numpy
import itertools
import matplotlib.pyplot as plt

# %%
filename = 'random_forest_3_state_space_search_estimators.csv'

# %%
df = pandas.read_csv(filename, index_col=0)

# %%
df
# Out:
#       estimators  max_features  max_depth  min_samples_split  \
# 0           40.0           5.0        NaN                2.0
# 1           40.0           5.0        NaN                2.0
# 2           40.0           5.0        NaN                2.0
# 3           40.0           5.0        NaN                2.0
# 4           40.0           5.0        NaN                2.0
# ...          ...           ...        ...                ...
# 2795        30.0           5.0        NaN                2.0
# 2796        30.0           5.0        NaN                2.0
# 2797        30.0           5.0        NaN                2.0
# 2798        30.0           5.0        NaN                2.0
# 2799        30.0           5.0        NaN                2.0
#
#       min_samples_leaf  max_leaf_nodes  fold  accuracy_in_sample  \
# 0                  1.0             NaN     0            0.999074
# 1                  1.0             NaN     1            0.999282
# 2                  1.0             NaN     2            0.999097
# 3                  1.0             NaN     3            0.999074
# 4                  1.0             NaN     4            0.999109
# ...                ...             ...   ...                 ...
# 2795               1.0             NaN    95            0.998183
# 2796               1.0             NaN    96            0.998044
# 2797               1.0             NaN    97            0.998449
# 2798               1.0             NaN    98            0.998542
# 2799               1.0             NaN    99            0.997963
#
#       accuracy_out_of_sample  oob_score       auc  public_score  private_score
# 0                   0.925544   0.945741  0.907265           NaN            NaN
# 1                   0.934708   0.945672  0.926094           NaN            NaN
# 2                   0.940435   0.945846  0.943423           NaN            NaN
# 3                   0.949599   0.945660  0.943867           NaN            NaN
# 4                   0.948454   0.945348  0.917162           NaN            NaN
# ...                      ...        ...       ...           ...            ...
# 2795                0.949541   0.944631  0.940602           NaN            NaN
# 2796                0.949541   0.944631  0.929672           NaN            NaN
# 2797                0.942661   0.945001  0.916415           NaN            NaN
# 2798                0.934633   0.944434  0.934805           NaN            NaN
# 2799                0.941514   0.944307  0.918637           NaN            NaN
#
# [2800 rows x 13 columns]

# %%
plt.figure()

positions = []
x = []
column = 'estimators'
metric = 'accuracy_in_sample'
x_label = 'number of estimators'
y_label = 'in sample accuracy'
box_width = 0.1
x_min = 0.9
x_max = 1100

for value in sorted(df[column].unique()):
    x.append(df[df[column] == value][metric])
    positions.append(value)

plt.boxplot(
    x,
    positions=positions,
    orientation='vertical',
    meanline=True,
    showmeans=True,
    widths=[box_width * position for position in positions],
)
plt.xscale('log')
plt.xlim(xmin=x_min, xmax=x_max)
plt.xlabel(x_label)
plt.ylabel(y_label)

None

# %%
plt.figure()

positions = []
x = []
column = 'estimators'
metric = 'accuracy_out_of_sample'
x_label = 'number of estimators'
y_label = 'out of sample accuracy'
box_width = 0.1
x_min = 0.9
x_max = 1100

for value in sorted(df[column].unique()):
    x.append(df[df[column] == value][metric])
    positions.append(value)

plt.boxplot(
    x,
    positions=positions,
    orientation='vertical',
    meanline=True,
    showmeans=True,
    widths=[box_width * position for position in positions],
)
plt.xscale('log')
plt.xlim(xmin=x_min, xmax=x_max)
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.savefig('random_forest_3_state_space_search_estimators-out_of_sample_accuracy.pdf')

None

# %%
plt.figure()

positions = []
x = []
column = 'estimators'
metric = 'oob_score'
x_label = 'number of estimators'
y_label = 'out of bag score'
box_width = 0.1
x_min = 0.9
x_max = 1100

for value in sorted(df[column].unique()):
    x.append(df[df[column] == value][metric])
    positions.append(value)

plt.boxplot(
    x,
    positions=positions,
    orientation='vertical',
    meanline=True,
    showmeans=True,
    widths=[box_width * position for position in positions],
)
plt.xscale('log')
plt.xlim(xmin=x_min, xmax=x_max)
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.savefig('random_forest_3_state_space_search_estimators-out_of_bag.pdf')

None

# %%
plt.figure()

positions = []
x = []
column = 'estimators'
metric = 'auc'
x_label = 'number of estimators'
y_label = 'AUC'
box_width = 0.1
x_min = 0.9
x_max = 1100

for value in sorted(df[column].unique()):
    x.append(df[df[column] == value][metric])
    positions.append(value)

plt.boxplot(
    x,
    positions=positions,
    orientation='vertical',
    meanline=True,
    showmeans=True,
    widths=[box_width * position for position in positions],
)
plt.xscale('log')
plt.xlim(xmin=x_min, xmax=x_max)
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.savefig('random_forest_3_state_space_search_estimators-auc.pdf')

None
