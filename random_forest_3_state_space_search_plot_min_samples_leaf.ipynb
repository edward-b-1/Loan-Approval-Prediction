# %% [markdown]
# # Plot

# %%
import math
import pandas
import numpy
import itertools
import matplotlib.pyplot as plt

# %%
filename = 'random_forest_3_state_space_search_min_samples_leaf.csv'

# %%
df = pandas.read_csv(filename, index_col=0)

# %%
df
# Out:
#       estimators  max_features  max_depth  min_samples_split  \
# 0          100.0           5.0        NaN                2.0
# 1          100.0           5.0        NaN                2.0
# 2          100.0           5.0        NaN                2.0
# 3          100.0           5.0        NaN                2.0
# 4          100.0           5.0        NaN                2.0
# ...          ...           ...        ...                ...
# 2695       100.0           5.0        NaN                2.0
# 2696       100.0           5.0        NaN                2.0
# 2697       100.0           5.0        NaN                2.0
# 2698       100.0           5.0        NaN                2.0
# 2699       100.0           5.0        NaN                2.0
#
#       min_samples_leaf  max_leaf_nodes  fold  accuracy_in_sample  \
# 0                  1.0             NaN     0            0.999919
# 1                  1.0             NaN     1            0.999942
# 2                  1.0             NaN     2            0.999965
# 3                  1.0             NaN     3            0.999965
# 4                  1.0             NaN     4            0.999942
# ...                ...             ...   ...                 ...
# 2695             900.0             NaN    95            0.918254
# 2696             900.0             NaN    96            0.918219
# 2697             900.0             NaN    97            0.918034
# 2698             900.0             NaN    98            0.920928
# 2699             900.0             NaN    99            0.919608
#
#       accuracy_out_of_sample  oob_score       auc  public_score  private_score
# 0                   0.927835   0.947130  0.914706           NaN            NaN
# 1                   0.936999   0.946702  0.933429           NaN            NaN
# 2                   0.942726   0.946725  0.942358           NaN            NaN
# 3                   0.949599   0.946737  0.941838           NaN            NaN
# 4                   0.948454   0.946852  0.928350           NaN            NaN
# ...                      ...        ...       ...           ...            ...
# 2695                0.927752   0.917560  0.930834           NaN            NaN
# 2696                0.916284   0.917270  0.914651           NaN            NaN
# 2697                0.907110   0.917745  0.892480           NaN            NaN
# 2698                0.904817   0.919724  0.902070           NaN            NaN
# 2699                0.917431   0.918451  0.896274           NaN            NaN
#
# [2700 rows x 13 columns]

# %%
plt.figure()

positions = []
x = []
column = 'min_samples_leaf'
metric = 'accuracy_in_sample'
x_label = 'minimum number of samples per leaf'
y_label = 'in sample accuracy'
box_width = 0.1
x_min = 0.9
x_max = 1100

for value in sorted(df[column].unique()):
    x.append(df[df[column] == value][metric])
    positions.append(value)

plt.boxplot(
    x,
    positions=positions,
    orientation='vertical',
    meanline=True,
    showmeans=True,
    widths=[box_width * position for position in positions],
)
plt.xscale('log')
plt.xlim(xmin=x_min, xmax=x_max)
plt.xlabel(x_label)
plt.ylabel(y_label)

None

# %%
plt.figure()

positions = []
x = []
column = 'min_samples_leaf'
metric = 'accuracy_out_of_sample'
x_label = 'minimum number of samples per leaf'
y_label = 'out of sample accuracy'
box_width = 0.1
x_min = 0.9
x_max = 1100

for value in sorted(df[column].unique()):
    x.append(df[df[column] == value][metric])
    positions.append(value)

plt.boxplot(
    x,
    positions=positions,
    orientation='vertical',
    meanline=True,
    showmeans=True,
    widths=[box_width * position for position in positions],
)
plt.xscale('log')
plt.xlim(xmin=x_min, xmax=x_max)
plt.xlabel(x_label)
plt.ylabel(y_label)

None

# %%
plt.figure()

positions = []
x = []
column = 'min_samples_leaf'
metric = 'oob_score'
x_label = 'minimum number of samples per leaf'
y_label = 'out of bag score'
box_width = 0.1
x_min = 0.9
x_max = 1100

for value in sorted(df[column].unique()):
    x.append(df[df[column] == value][metric])
    positions.append(value)

plt.boxplot(
    x,
    positions=positions,
    orientation='vertical',
    meanline=True,
    showmeans=True,
    widths=[box_width * position for position in positions],
)
plt.xscale('log')
plt.xlim(xmin=x_min, xmax=x_max)
plt.xlabel(x_label)
plt.ylabel(y_label)

None

# %%
plt.figure()

positions = []
x = []
column = 'min_samples_leaf'
metric = 'auc'
x_label = 'minimum number of samples per leaf'
y_label = 'AUC'
box_width = 0.1
x_min = 0.9
x_max = 1100

for value in sorted(df[column].unique()):
    x.append(df[df[column] == value][metric])
    positions.append(value)

plt.boxplot(
    x,
    positions=positions,
    orientation='vertical',
    meanline=True,
    showmeans=True,
    widths=[box_width * position for position in positions],
)
plt.xscale('log')
plt.xlim(xmin=x_min, xmax=x_max)
plt.xlabel(x_label)
plt.ylabel(y_label)

None
