# %% [markdown]
# # Plot

# %%
import math
import pandas
import numpy
import itertools
import matplotlib.pyplot as plt

# %%
filename = 'random_forest_3_state_space_search_max_features.csv'

# %%
df = pandas.read_csv(filename, index_col=0)

# %%
df
# Out:
#       estimators  max_features  max_depth  min_samples_split  \
# 0          100.0           1.0        NaN                2.0
# 1          100.0           1.0        NaN                2.0
# 2          100.0           1.0        NaN                2.0
# 3          100.0           1.0        NaN                2.0
# 4          100.0           1.0        NaN                2.0
# ...          ...           ...        ...                ...
# 1895       100.0          19.0        NaN                2.0
# 1896       100.0          19.0        NaN                2.0
# 1897       100.0          19.0        NaN                2.0
# 1898       100.0          19.0        NaN                2.0
# 1899       100.0          19.0        NaN                2.0
#
#       min_samples_leaf  max_leaf_nodes  fold  accuracy_in_sample  \
# 0                  1.0             NaN     0            0.999954
# 1                  1.0             NaN     1            0.999942
# 2                  1.0             NaN     2            0.999919
# 3                  1.0             NaN     3            0.999954
# 4                  1.0             NaN     4            0.999954
# ...                ...             ...   ...                 ...
# 1895               1.0             NaN    95            0.999931
# 1896               1.0             NaN    96            0.999919
# 1897               1.0             NaN    97            0.999942
# 1898               1.0             NaN    98            0.999942
# 1899               1.0             NaN    99            0.999977
#
#       accuracy_out_of_sample  oob_score       auc  public_score  private_score
# 0                   0.924399   0.943820  0.908327           NaN            NaN
# 1                   0.933562   0.944491  0.919467           NaN            NaN
# 2                   0.940435   0.943681  0.932992           NaN            NaN
# 3                   0.946163   0.943531  0.934781           NaN            NaN
# 4                   0.946163   0.943380  0.927028           NaN            NaN
# ...                      ...        ...       ...           ...            ...
# 1895                0.948394   0.946911  0.945911           NaN            NaN
# 1896                0.950688   0.946749  0.941627           NaN            NaN
# 1897                0.943807   0.946911  0.958575           NaN            NaN
# 1898                0.935780   0.947131  0.947769           NaN            NaN
# 1899                0.942661   0.946749  0.933425           NaN            NaN
#
# [1900 rows x 13 columns]

# %%
plt.figure()

positions = []
x = []
column = 'max_features'
metric = 'accuracy_in_sample'
x_label = 'maximum number of features'
y_label = 'in sample accuracy'
box_width = 0.04
x_min = 0.9
x_max = 20

for value in sorted(df[column].unique()):
    x.append(df[df[column] == value][metric])
    positions.append(value)

plt.boxplot(
    x,
    positions=positions,
    orientation='vertical',
    meanline=True,
    showmeans=True,
    widths=[box_width * position for position in positions],
)
plt.xscale('log')
plt.xlim(xmin=x_min, xmax=x_max)
plt.xlabel(x_label)
plt.ylabel(y_label)

None

# %%
plt.figure()

positions = []
x = []
column = 'max_features'
metric = 'accuracy_out_of_sample'
x_label = 'maximum number of features'
y_label = 'out of sample accuracy'
box_width = 0.04
x_min = 0.9
x_max = 20

for value in sorted(df[column].unique()):
    x.append(df[df[column] == value][metric])
    positions.append(value)

plt.boxplot(
    x,
    positions=positions,
    orientation='vertical',
    meanline=True,
    showmeans=True,
    widths=[box_width * position for position in positions],
)
plt.xscale('log')
plt.xlim(xmin=x_min, xmax=x_max)
plt.xlabel(x_label)
plt.ylabel(y_label)

None

# %%
plt.figure()

positions = []
x = []
column = 'max_features'
metric = 'oob_score'
x_label = 'maximum number of features'
y_label = 'out of bag score'
box_width = 0.04
x_min = 0.9
x_max = 20

for value in sorted(df[column].unique()):
    x.append(df[df[column] == value][metric])
    positions.append(value)

plt.boxplot(
    x,
    positions=positions,
    orientation='vertical',
    meanline=True,
    showmeans=True,
    widths=[box_width * position for position in positions],
)
plt.xscale('log')
plt.xlim(xmin=x_min, xmax=x_max)
plt.xlabel(x_label)
plt.ylabel(y_label)

None

# %%
plt.figure()

positions = []
x = []
column = 'max_features'
metric = 'auc'
x_label = 'maximum number of features'
y_label = 'AUC'
box_width = 0.04
x_min = 0.9
x_max = 20

for value in sorted(df[column].unique()):
    x.append(df[df[column] == value][metric])
    positions.append(value)

plt.boxplot(
    x,
    positions=positions,
    orientation='vertical',
    meanline=True,
    showmeans=True,
    widths=[box_width * position for position in positions],
)
plt.xscale('log')
plt.xlim(xmin=x_min, xmax=x_max)
plt.xlabel(x_label)
plt.ylabel(y_label)

None
