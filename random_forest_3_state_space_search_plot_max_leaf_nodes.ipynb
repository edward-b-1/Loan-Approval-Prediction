# %% [markdown]
# # Plot

# %%
import math
import pandas
import numpy
import itertools
import matplotlib.pyplot as plt

# %%
filename = 'random_forest_3_state_space_search_max_leaf_nodes.csv'

# %%
df = pandas.read_csv(filename, index_col=0)

# %%
df
# Out:
#       estimators  max_features  max_depth  min_samples_split  \
# 0          100.0           5.0        NaN                2.0
# 1          100.0           5.0        NaN                2.0
# 2          100.0           5.0        NaN                2.0
# 3          100.0           5.0        NaN                2.0
# 4          100.0           5.0        NaN                2.0
# ...          ...           ...        ...                ...
# 2595       100.0           5.0        NaN                2.0
# 2596       100.0           5.0        NaN                2.0
# 2597       100.0           5.0        NaN                2.0
# 2598       100.0           5.0        NaN                2.0
# 2599       100.0           5.0        NaN                2.0
#
#       min_samples_leaf  max_leaf_nodes  fold  accuracy_in_sample  \
# 0                  1.0             2.0     0            0.833301
# 1                  1.0             2.0     1            0.833358
# 2                  1.0             2.0     2            0.833370
# 3                  1.0             2.0     3            0.833196
# 4                  1.0             2.0     4            0.838509
# ...                ...             ...   ...                 ...
# 2595               1.0           900.0    95            0.949446
# 2596               1.0           900.0    96            0.949527
# 2597               1.0           900.0    97            0.949561
# 2598               1.0           900.0    98            0.949619
# 2599               1.0           900.0    99            0.949527
#
#       accuracy_out_of_sample  oob_score       auc  public_score  private_score
# 0                   0.830470   0.835523  0.818281           NaN            NaN
# 1                   0.824742   0.836287  0.874923           NaN            NaN
# 2                   0.823597   0.835719  0.890568           NaN            NaN
# 3                   0.840779   0.835465  0.894664           NaN            NaN
# 4                   0.856816   0.839076  0.886988           NaN            NaN
# ...                      ...        ...       ...           ...            ...
# 2595                0.949541   0.945997  0.951877           NaN            NaN
# 2596                0.948394   0.945892  0.940895           NaN            NaN
# 2597                0.944954   0.946066  0.934302           NaN            NaN
# 2598                0.930046   0.946159  0.938734           NaN            NaN
# 2599                0.942661   0.946170  0.928030           NaN            NaN
#
# [2600 rows x 13 columns]

# %%
plt.figure()

positions = []
x = []
column = 'max_leaf_nodes'
metric = 'accuracy_in_sample'
x_label = 'maximum number of leaf nodes'
y_label = 'in sample accuracy'
box_width = 0.1
x_min = 0.9
x_max = 1100

for value in sorted(df[column].unique()):
    x.append(df[df[column] == value][metric])
    positions.append(value)

plt.boxplot(
    x,
    positions=positions,
    orientation='vertical',
    meanline=True,
    showmeans=True,
    widths=[box_width * position for position in positions],
)
plt.xscale('log')
plt.xlim(xmin=x_min, xmax=x_max)
plt.xlabel(x_label)
plt.ylabel(y_label)

None

# %%
plt.figure()

positions = []
x = []
column = 'max_leaf_nodes'
metric = 'accuracy_out_of_sample'
x_label = 'maximum number of leaf nodes'
y_label = 'out of sample accuracy'
box_width = 0.1
x_min = 0.9
x_max = 1100

for value in sorted(df[column].unique()):
    x.append(df[df[column] == value][metric])
    positions.append(value)

plt.boxplot(
    x,
    positions=positions,
    orientation='vertical',
    meanline=True,
    showmeans=True,
    widths=[box_width * position for position in positions],
)
plt.xscale('log')
plt.xlim(xmin=x_min, xmax=x_max)
plt.xlabel(x_label)
plt.ylabel(y_label)

None

# %%
plt.figure()

positions = []
x = []
column = 'max_leaf_nodes'
metric = 'oob_score'
x_label = 'maximum number of leaf nodes'
y_label = 'out of bag score'
box_width = 0.1
x_min = 0.9
x_max = 1100

for value in sorted(df[column].unique()):
    x.append(df[df[column] == value][metric])
    positions.append(value)

plt.boxplot(
    x,
    positions=positions,
    orientation='vertical',
    meanline=True,
    showmeans=True,
    widths=[box_width * position for position in positions],
)
plt.xscale('log')
plt.xlim(xmin=x_min, xmax=x_max)
plt.xlabel(x_label)
plt.ylabel(y_label)

None

# %%
plt.figure()

positions = []
x = []
column = 'max_leaf_nodes'
metric = 'auc'
x_label = 'maximum number of leaf nodes'
y_label = 'AUC'
box_width = 0.1
x_min = 0.9
x_max = 1100

for value in sorted(df[column].unique()):
    x.append(df[df[column] == value][metric])
    positions.append(value)

plt.boxplot(
    x,
    positions=positions,
    orientation='vertical',
    meanline=True,
    showmeans=True,
    widths=[box_width * position for position in positions],
)
plt.xscale('log')
plt.xlim(xmin=x_min, xmax=x_max)
plt.xlabel(x_label)
plt.ylabel(y_label)

None
