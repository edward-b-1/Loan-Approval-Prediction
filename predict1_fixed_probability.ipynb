# %% [markdown]
# # Prediction based on probability - Assign P=0.5

# %%
import pandas
import numpy
import matplotlib.pyplot as plt

# %%
import loan_approval_lib

# %%
data = loan_approval_lib.load_data()

# %%
data_train = data['train']

# %%
data_test = data['test']

# %%
len(data_test)
# Out:
# 39098

# %%
data_test
# Out:
#           id  person_age  person_income person_home_ownership  \
# 0      58645          23          69000                  RENT
# 1      58646          26          96000              MORTGAGE
# 2      58647          26          30000                  RENT
# 3      58648          33          50000                  RENT
# 4      58649          26         102000              MORTGAGE
# ...      ...         ...            ...                   ...
# 39093  97738          22          31200              MORTGAGE
# 39094  97739          22          48000              MORTGAGE
# 39095  97740          51          60000              MORTGAGE
# 39096  97741          22          36000              MORTGAGE
# 39097  97742          31          45000                  RENT
#
#        person_emp_length        loan_intent loan_grade  loan_amnt  \
# 0                    3.0    HOMEIMPROVEMENT          F      25000
# 1                    6.0           PERSONAL          C      10000
# ...

# %%
data_test['loan_status'] = 0.5

# %%
data_test_submission = data_test[['id', 'loan_status']]

# %%
data_test_submission
# Out:
#           id  loan_status
# 0      58645          0.5
# 1      58646          0.5
# 2      58647          0.5
# 3      58648          0.5
# 4      58649          0.5
# ...      ...          ...
# 39093  97738          0.5
# 39094  97739          0.5
# 39095  97740          0.5
# 39096  97741          0.5
# 39097  97742          0.5
#
# [39098 rows x 2 columns]

# %%
data_test_submission.to_csv('data_test_submission_1.csv', index=False)
