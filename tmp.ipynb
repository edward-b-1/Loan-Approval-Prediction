# %%
import pandas
import numpy

# %%
filename = 'random_forest_3_state_space_search_max_features.csv'

# %%
df = pandas.read_csv(filename, index_col=0)

# %%
df
# Out:
#       estimators  max_features  max_depth  min_samples_split  \
# 0          100.0           2.0        NaN                2.0
# 1          100.0           2.0        NaN                2.0
# 2          100.0           2.0        NaN                2.0
# 3          100.0           2.0        NaN                2.0
# 4          100.0           2.0        NaN                2.0
# ...          ...           ...        ...                ...
# 998        100.0           5.0        NaN                2.0
# 999        100.0           5.0        NaN                2.0
# 1000       100.0           6.0        NaN                2.0
# 1001       100.0           6.0        NaN                2.0
# 1002       100.0           6.0        NaN                2.0
#
#       min_samples_leaf  max_leaf_nodes  fold  accuracy_in_sample  \
# 0                  1.0             NaN     0            0.999954
# 1                  1.0             NaN     1            0.999942
# ...

# %%
df_select = df

# %%
n_estimators = 100
max_features = 2
max_depth = None
min_samples_split = 2
min_samples_leaf = 1
max_leaf_nodes = None

# %%
df_select = df_select[df_select['estimators'] == n_estimators]

# %%
df_select
# Out:
#       estimators  max_features  max_depth  min_samples_split  \
# 0          100.0           2.0        NaN                2.0
# 1          100.0           2.0        NaN                2.0
# 2          100.0           2.0        NaN                2.0
# 3          100.0           2.0        NaN                2.0
# 4          100.0           2.0        NaN                2.0
# ...          ...           ...        ...                ...
# 998        100.0           5.0        NaN                2.0
# 999        100.0           5.0        NaN                2.0
# 1000       100.0           6.0        NaN                2.0
# 1001       100.0           6.0        NaN                2.0
# 1002       100.0           6.0        NaN                2.0
#
#       min_samples_leaf  max_leaf_nodes  fold  accuracy_in_sample  \
# 0                  1.0             NaN     0            0.999954
# 1                  1.0             NaN     1            0.999942
# ...

# %%
df_select = df_select[df_select['max_features'] == float(max_features)] if max_features is not None else df_select[df_select['max_features'].isna()]

# %%
df_select
# Out:
#      estimators  max_features  max_depth  min_samples_split  min_samples_leaf  \
# 0         100.0           2.0        NaN                2.0               1.0
# 1         100.0           2.0        NaN                2.0               1.0
# 2         100.0           2.0        NaN                2.0               1.0
# 3         100.0           2.0        NaN                2.0               1.0
# 4         100.0           2.0        NaN                2.0               1.0
# ..          ...           ...        ...                ...               ...
# 695       100.0           2.0        NaN                2.0               1.0
# 696       100.0           2.0        NaN                2.0               1.0
# 697       100.0           2.0        NaN                2.0               1.0
# 698       100.0           2.0        NaN                2.0               1.0
# 699       100.0           2.0        NaN                2.0               1.0
#
# ...

# %%
df_select = df_select[df_select['max_depth'] == float(max_depth)] if max_depth is not None else df_select[df_select['max_depth'].isna()]

# %%
df_select
# Out:
#      estimators  max_features  max_depth  min_samples_split  min_samples_leaf  \
# 0         100.0           2.0        NaN                2.0               1.0
# 1         100.0           2.0        NaN                2.0               1.0
# 2         100.0           2.0        NaN                2.0               1.0
# 3         100.0           2.0        NaN                2.0               1.0
# 4         100.0           2.0        NaN                2.0               1.0
# ..          ...           ...        ...                ...               ...
# 695       100.0           2.0        NaN                2.0               1.0
# 696       100.0           2.0        NaN                2.0               1.0
# 697       100.0           2.0        NaN                2.0               1.0
# 698       100.0           2.0        NaN                2.0               1.0
# 699       100.0           2.0        NaN                2.0               1.0
#
# ...
