# %% [markdown]
# # Plot

# %%
import math
import pandas
import numpy
import itertools
import matplotlib.pyplot as plt

# %%
filename = 'random_forest_3_state_space_search_min_samples_split.csv'

# %%
df = pandas.read_csv(filename, index_col=0)

# %%
df
# Out:
#       estimators  max_features  max_depth  min_samples_split  \
# 0          100.0           5.0        NaN                2.0
# 1          100.0           5.0        NaN                2.0
# 2          100.0           5.0        NaN                2.0
# 3          100.0           5.0        NaN                2.0
# 4          100.0           5.0        NaN                2.0
# ...          ...           ...        ...                ...
# 2595       100.0           5.0        NaN              900.0
# 2596       100.0           5.0        NaN              900.0
# 2597       100.0           5.0        NaN              900.0
# 2598       100.0           5.0        NaN              900.0
# 2599       100.0           5.0        NaN              900.0
#
#       min_samples_leaf  max_leaf_nodes  fold  accuracy_in_sample  \
# 0                  1.0             NaN     0            0.999954
# 1                  1.0             NaN     1            0.999942
# ...

# %%
plt.figure()

positions = []
x = []
column = 'min_samples_split'
metric = 'accuracy_in_sample'
x_label = 'minumum number of samples for split'
y_label = 'in sample accuracy'
box_width = 0.04
x_min = 1
x_max = 1100

for value in sorted(df[column].unique()):
    x.append(df[df[column] == value][metric])
    positions.append(value)

plt.boxplot(
    x,
    positions=positions,
    orientation='vertical',
    meanline=True,
    showmeans=True,
    widths=[box_width * position for position in positions],
)
plt.xscale('log')
plt.xlim(xmin=x_min, xmax=x_max)
plt.xlabel(x_label)
plt.ylabel(y_label)

None

# %%
plt.figure()

positions = []
x = []
column = 'min_samples_split'
metric = 'accuracy_out_of_sample'
x_label = 'minumum number of samples for split'
y_label = 'out of sample accuracy'
box_width = 0.04
x_min = 1
x_max = 1100

for value in sorted(df[column].unique()):
    x.append(df[df[column] == value][metric])
    positions.append(value)

plt.boxplot(
    x,
    positions=positions,
    orientation='vertical',
    meanline=True,
    showmeans=True,
    widths=[box_width * position for position in positions],
)
plt.xscale('log')
plt.xlim(xmin=x_min, xmax=x_max)
plt.xlabel(x_label)
plt.ylabel(y_label)

None

# %%
plt.figure()

positions = []
x = []
column = 'min_samples_split'
metric = 'oob_score'
x_label = 'minumum number of samples for split'
y_label = 'out of bag score'
box_width = 0.04
x_min = 1
x_max = 1100

for value in sorted(df[column].unique()):
    x.append(df[df[column] == value][metric])
    positions.append(value)

plt.boxplot(
    x,
    positions=positions,
    orientation='vertical',
    meanline=True,
    showmeans=True,
    widths=[box_width * position for position in positions],
)
plt.xscale('log')
plt.xlim(xmin=x_min, xmax=x_max)
plt.xlabel(x_label)
plt.ylabel(y_label)

None

# %%
plt.figure()

positions = []
x = []
column = 'min_samples_split'
metric = 'auc'
x_label = 'minumum number of samples for split'
y_label = 'AUC'
box_width = 0.04
x_min = 1
x_max = 1100

for value in sorted(df[column].unique()):
    x.append(df[df[column] == value][metric])
    positions.append(value)

plt.boxplot(
    x,
    positions=positions,
    orientation='vertical',
    meanline=True,
    showmeans=True,
    widths=[box_width * position for position in positions],
)
plt.xscale('log')
plt.xlim(xmin=x_min, xmax=x_max)
plt.xlabel(x_label)
plt.ylabel(y_label)

None
